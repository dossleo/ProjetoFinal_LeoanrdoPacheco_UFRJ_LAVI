# %%
import models
from models import get_raw_data
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
pasta = 'database/dados_tratados/ordens_1'
arquivos = os.listdir(pasta)
arquivo = arquivos[0]
coluna = 1

# %%
sinal = get_raw_data.GetData(pasta,arquivo,coluna).Get()

# %%
plt.plot(range(len(sinal)),sinal)
plt.show()
