# %%
import models
from models import get_raw_data, normalizar_sinal
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
pasta = 'database/dados_tratados/harmonicos_1'
arquivos = os.listdir(pasta)
arquivo = 'dados_extraidos_concatenado.csv'
coluna = 1

# %%
sinal = get_raw_data.GetData(pasta,arquivo).GetDataframe()

# %%
sinal
# Out:
#        rotacao_hz   maximo       rms  assimetria   curtose  fator_crista  \
# 0            12.0  0.57560  0.306913    0.383296  2.226203      1.875448
# 1            12.0  0.57560  0.307258    0.384193  2.236599      1.873342
# 2            12.0  0.55983  0.307356    0.382105  2.235120      1.821441
# 3            12.0  0.55983  0.307468    0.394888  2.281622      1.820774
# 4            12.0  0.54912  0.306421    0.392862  2.265882      1.792046
# ...           ...      ...       ...         ...       ...           ...
# 44091        57.6  5.96030  2.234032    0.063426  1.799888      2.667956
# 44092        57.6  5.79780  2.209433    0.074974  1.811143      2.624112
# 44093        57.6  6.45050  2.213064    0.065017  1.803834      2.914738
# 44094        57.6  6.45050  2.211838    0.064160  1.830753      2.916353
# 44095        57.6  6.52120  2.208495    0.054521  1.848734      2.952780
#
#        pot_ball_fault  pot_outer_race  pot_rotacao_hz  \
# 0         1503.360530     1436.422977      937.970508
# 1         1570.207174     1337.103630     1014.435718
# 2         1474.675067     1195.422075      979.954003
# 3         1423.925643     1416.511165     1046.839315
# 4         1372.304026     1193.949406     1056.775495
# ...               ...             ...             ...
# 44091    41648.033696    28036.213037   246306.770482
# 44092    29427.821596    21288.392111   245547.727294
# 44093    36034.255725    28697.651169   242095.698268
# 44094    36476.761034    24205.029947   242375.352488
# 44095    29778.232327    20769.815647   239812.427682
#
#                           sensor          defeito
# 0      rolamento_interno_radial1           normal
# 1      rolamento_interno_radial1           normal
# 2      rolamento_interno_radial1           normal
# 3      rolamento_interno_radial1           normal
# 4      rolamento_interno_radial1           normal
# ...                          ...              ...
# 44091  rolamento_externo_radial2  outer_race_alto
# 44092  rolamento_externo_radial2  outer_race_alto
# 44093  rolamento_externo_radial2  outer_race_alto
# 44094  rolamento_externo_radial2  outer_race_alto
# 44095  rolamento_externo_radial2  outer_race_alto
#
# [44096 rows x 11 columns]

# %%
dado_normal = get_raw_data.GetData(pasta,"Dados_Normalizados.csv").GetDataframe()
dado_normal
# Out:
#        rotacao_hz    maximo       rms  assimetria   curtose  fator_crista  \
# 0            0.00  0.126664  0.275512    0.473520  0.154328      0.094385
# 1            0.00  0.126664  0.275853    0.474629  0.157274      0.094035
# 2            0.00  0.122756  0.275949    0.472048  0.156855      0.085411
# 3            0.00  0.122756  0.276060    0.487852  0.170034      0.085300
# 4            0.00  0.120102  0.275026    0.485347  0.165573      0.080526
# ...           ...       ...       ...         ...       ...           ...
# 44091        0.95  1.461053  2.178163    0.078068  0.033507      0.226078
# 44092        0.95  1.420783  2.153876    0.092345  0.036697      0.218792
# 44093        0.95  1.582530  2.157460    0.080035  0.034625      0.267086
# 44094        0.95  1.582530  2.156250    0.078975  0.042254      0.267354
# 44095        0.95  1.600050  2.152950    0.067059  0.047350      0.273407
#
#        pot_ball_fault  pot_outer_race  pot_rotacao_hz  sensor          defeito
# 0            0.047405        0.045160        0.028439     0.0           normal
# 1            0.049648        0.041828        0.031004     0.0           normal
# 2            0.046443        0.037075        0.029847     0.0           normal
# 3            0.044740        0.044492        0.032091     0.0           normal
# 4            0.043009        0.037026        0.032424     0.0           normal
# ...               ...             ...             ...     ...              ...
# 44091        1.394101        0.937478        8.259597     1.0  outer_race_alto
# 44092        0.984161        0.711115        8.234134     1.0  outer_race_alto
# 44093        1.205781        0.959667        8.118332     1.0  outer_race_alto
# 44094        1.220625        0.808957        8.127713     1.0  outer_race_alto
# 44095        0.995916        0.693719        8.041737     1.0  outer_race_alto
#
# [44096 rows x 11 columns]

# %%
dado_normal[dado_normal['defeito']=='normal'].describe()
# Out:
#         rotacao_hz       maximo          rms   assimetria      curtose  \
# count  1568.000000  1568.000000  1568.000000  1568.000000  1568.000000
# mean      0.498044     0.227941     0.217479     0.175463     0.314679
# std       0.295952     0.202921     0.180266     0.152885     0.138093
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.250000     0.027109     0.020843     0.068333     0.205452
# 50%       0.491667     0.187678     0.224129     0.124439     0.333695
# 75%       0.745833     0.365232     0.352301     0.238886     0.399077
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        fator_crista  pot_ball_fault  pot_outer_race  pot_rotacao_hz  \
# count   1568.000000     1568.000000     1568.000000     1568.000000
# mean       0.402925        0.102562        0.138350        0.249189
# std        0.187498        0.087189        0.149231        0.250454
# min        0.000000        0.000004        0.004753        0.000000
# 25%        0.229362        0.036320        0.038944        0.051550
# 50%        0.397702        0.075505        0.083554        0.120613
# 75%        0.529751        0.153492        0.186157        0.367907
# max        1.000000        0.418670        0.919614        1.000000
#
#             sensor
# count  1568.000000
# mean      0.500000
# std       0.395411
# min       0.000000
# 25%       0.187500
# 50%       0.500000
# 75%       0.812500
# max       1.000000

# %%
feature = 'soma_relativa_rotacao_hz'
feature_analisada = sinal[feature]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\leona\Documents\ProjetoFinal_LeonardoPacheco_UFRJ_LAVI\.venv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\leona\Documents\ProjetoFinal_LeonardoPacheco_UFRJ_LAVI\.venv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\leona\Documents\ProjetoFinal_LeonardoPacheco_UFRJ_LAVI\.venv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'soma_relativa_rotacao_hz'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 feature = 'soma_relativa_rotacao_hz'
# ----> 2 feature_analisada = sinal[feature]
#
# File c:\Users\leona\Documents\ProjetoFinal_LeonardoPacheco_UFRJ_LAVI\.venv\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\leona\Documents\ProjetoFinal_LeonardoPacheco_UFRJ_LAVI\.venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'soma_relativa_rotacao_hz'

# %%
plt.plot(range(len(feature_analisada)),feature_analisada)
plt.title(feature)
plt.show()

# %%
defeito = "desbalanceamento_alto"
sensor = 'rolamento_interno_axial'

df_defeito = sinal[sinal["defeito"] == defeito]
df_defeito = df_defeito[df_defeito["sensor"] == sensor]

rotacao = df_defeito['rotacao_hz']
feature_analisada = df_defeito[feature]

# %%
plt.plot(range(len(rotacao)),rotacao)
plt.title('Rotação [Hz]')
plt.show()

# %%
plt.plot(range(len(feature_analisada)),feature_analisada)
plt.title(feature)
plt.show()

# %%
print(sinal)
