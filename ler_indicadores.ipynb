# %%
import models
from models import get_raw_data
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
pasta = 'database/dados_tratados/harmonicos_1'
arquivos = os.listdir(pasta)
arquivo = 'dados_extraidos_concatenado.csv'
coluna = 1

# %%
sinal = get_raw_data.GetData(pasta,arquivo).GetDataframe()

# %%
sinal
# Out:
#        rotacao_hz   maximo       rms  assimetria   curtose  fator_crista  \
# 0            12.0  0.57560  0.306897    0.386069  2.242362      1.875549
# 1            12.0  0.57560  0.306791    0.384819  2.244944      1.876196
# 2            12.0  0.60436  0.306937    0.388140  2.257479      1.969006
# 3            12.0  0.60436  0.307081    0.387783  2.258949      1.968078
# 4            12.0  0.60436  0.307170    0.389240  2.258827      1.967508
# ...           ...      ...       ...         ...       ...           ...
# 77163        57.6  6.45050  2.219950    0.061582  1.813858      2.905696
# 77164        57.6  6.52120  2.218558    0.061015  1.817330      2.939387
# 77165        57.6  6.52120  2.211488    0.066015  1.823942      2.948784
# 77166        57.6  6.52120  2.214738    0.064983  1.824876      2.944456
# 77167        57.6  6.52120  2.213178    0.070288  1.828150      2.946533
#
#        soma_relativa_ball_fault  soma_ball_fault  soma_relativa_outer_race  \
# 0                      0.003766      6867.680722                  0.002560
# 1                      0.003824      6963.622485                  0.002432
# 2                      0.004219      7707.031886                  0.002689
# 3                      0.004301      7852.653438                  0.002598
# 4                      0.004152      7578.403600                  0.002940
# ...                         ...              ...                       ...
# 77163                  0.010627    102889.990296                  0.010291
# 77164                  0.010151     98800.811542                  0.009880
# 77165                  0.008153     78044.061759                  0.010223
# 77166                  0.009669     93783.108240                  0.010174
# 77167                  0.009498     91765.418096                  0.010039
#
#        soma_outer_race  soma_relativa_rotacao_hz  soma_rotacao_hz  \
# 0          4669.155764                  0.002861      5218.156645
# 1          4428.999723                  0.003130      5699.318918
# 2          4910.826038                  0.003054      5578.866686
# 3          4743.891812                  0.003002      5480.830825
# 4          5367.324345                  0.002971      5423.683832
# ...                ...                       ...              ...
# 77163     99637.364417                  0.061733    597701.893537
# 77164     96157.447190                  0.060249    586389.120490
# 77165     97852.440963                  0.059621    570709.454444
# 77166     98682.458465                  0.057254    555338.610698
# 77167     96985.192847                  0.056217    543113.096813
#
#                           sensor          defeito
# 0      rolamento_interno_radial1           normal
# 1      rolamento_interno_radial1           normal
# 2      rolamento_interno_radial1           normal
# 3      rolamento_interno_radial1           normal
# 4      rolamento_interno_radial1           normal
# ...                          ...              ...
# 77163  rolamento_externo_radial2  outer_race_alto
# 77164  rolamento_externo_radial2  outer_race_alto
# 77165  rolamento_externo_radial2  outer_race_alto
# 77166  rolamento_externo_radial2  outer_race_alto
# 77167  rolamento_externo_radial2  outer_race_alto
#
# [77168 rows x 14 columns]

# %%
feature = 'soma_relativa_rotacao_hz'
feature_analisada = sinal[feature]

# %%
plt.plot(range(len(feature_analisada)),feature_analisada)
plt.title(feature)
plt.show()

# %%
defeito = "desbalanceamento_alto"
sensor = 'rolamento_interno_axial'

df_defeito = sinal[sinal["defeito"] == defeito]
df_defeito = df_defeito[df_defeito["sensor"] == sensor]

rotacao = df_defeito['rotacao_hz']
feature_analisada = df_defeito[feature]

# %%
plt.plot(range(len(rotacao)),rotacao)
plt.title('Rotação [Hz]')
plt.show()

# %%
plt.plot(range(len(feature_analisada)),feature_analisada)
plt.title(feature)
plt.show()

# %%
print(sinal)
